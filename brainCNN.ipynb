# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, roc_auc_score, cohen_kappa_score, precision_score, recall_score, accuracy_score, confusion_matrix
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input
from keras.models import Sequential
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
#from keras.layers.normalization import BatchNormalization
from keras.models import Model, Sequential
from keras.applications.xception import Xception
from keras.applications import *
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from PIL import Image
import random
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from keras.callbacks import EarlyStopping
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_set= '/content/drive/MyDrive/BraintumorData'

# %%
for i,d in enumerate([image_set]):
    filepaths=[]
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        classpath=os.path.join(d,klass)
        if os.path.isdir(classpath):
            flist=os.listdir(classpath)
            for f in flist:
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(klass)
    Fseries= pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    brain_df=pd.concat([Fseries, Lseries], axis=1)
df=pd.concat([brain_df], axis =0).reset_index(drop=True)# make a combined dataframe

print(df['labels'].value_counts())
# Out:
# BrainTumor    2513
# Healthy       2087
# Name: labels, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_split=.6
test_split=.2
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), ' _test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  2760  _test_df length:  920   valid_df length:  920

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
height=224
width=224
channels=3
batch_size=32
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    return img/127.5-1  # scale pixel between -1 and +1
gen=ImageDataGenerator(preprocessing_function=scalar)
train_set=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_set=gen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
validate_set=gen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
#classes=list(train_gen.class_indices.keys())
#class_count=len(classes)
# Out:
# test batch size:  46   test steps:  20
# Found 2760 validated image filenames belonging to 2 classes.
# Found 920 validated image filenames belonging to 2 classes.
# Found 920 validated image filenames belonging to 2 classes.

# %%
IMAGE_SIZE = [224, 224]

# %%
# importing libraries

import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from  tensorflow import keras

# %%
model_1 = keras.models.Sequential()

model_1.add(keras.layers.Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3)))
model_1.add(keras.layers.Dropout(0.1))
model_1.add(keras.layers.MaxPooling2D())

model_1.add(keras.layers.Conv2D(64, 3, activation='relu'))
model_1.add(keras.layers.Dropout(0.15))
model_1.add(keras.layers.MaxPooling2D())

model_1.add(keras.layers.Flatten())
model_1.add(keras.layers.Dense(256, activation='relu'))
model_1.add(keras.layers.Dense(2, activation='softmax'))

model_1.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 222, 222, 32)      896
#
#  dropout_2 (Dropout)         (None, 222, 222, 32)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 109, 109, 64)      18496
#
#  dropout_3 (Dropout)         (None, 109, 109, 64)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 186624)            0
#
#  dense_2 (Dense)             (None, 256)               47776000
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 47,795,906
# Trainable params: 47,795,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
# COMPILING THE MODEL

model_1.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
#executing the model
history = model_1.fit(train_set, validation_data = (validate_set), epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - 966s 11s/step - loss: 1.1830 - accuracy: 0.7645 - val_loss: 0.2121 - val_accuracy: 0.9359
# Epoch 2/50
# 87/87 [==============================] - 20s 229ms/step - loss: 0.1109 - accuracy: 0.9630 - val_loss: 0.2074 - val_accuracy: 0.9370
# Epoch 3/50
# 87/87 [==============================] - 19s 219ms/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.1568 - val_accuracy: 0.9565
# Epoch 4/50
# 87/87 [==============================] - 20s 235ms/step - loss: 0.0067 - accuracy: 0.9989 - val_loss: 0.1920 - val_accuracy: 0.9435
# Epoch 5/50
# 87/87 [==============================] - 20s 232ms/step - loss: 0.0167 - accuracy: 0.9960 - val_loss: 0.2159 - val_accuracy: 0.9424
# Epoch 6/50
# 87/87 [==============================] - 21s 238ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.1869 - val_accuracy: 0.9413
# Epoch 7/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.2528 - val_accuracy: 0.9446
# Epoch 8/50
# 87/87 [==============================] - 20s 234ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.2368 - val_accuracy: 0.9511
# Epoch 9/50
# 87/87 [==============================] - 19s 218ms/step - loss: 6.6704e-04 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9565
# Epoch 10/50
# 87/87 [==============================] - 20s 233ms/step - loss: 1.4331e-04 - accuracy: 1.0000 - val_loss: 0.2724 - val_accuracy: 0.9565
# Epoch 11/50
# 87/87 [==============================] - 19s 222ms/step - loss: 7.2249e-05 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.9543
# Epoch 12/50
# 87/87 [==============================] - 20s 228ms/step - loss: 5.5080e-05 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.9543
# Epoch 13/50
# 87/87 [==============================] - 19s 222ms/step - loss: 3.9988e-05 - accuracy: 1.0000 - val_loss: 0.2850 - val_accuracy: 0.9543
# Epoch 14/50
# 87/87 [==============================] - 20s 233ms/step - loss: 2.6137e-05 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9554
# Epoch 15/50
# 87/87 [==============================] - 19s 221ms/step - loss: 2.2818e-05 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9554
# Epoch 16/50
# 87/87 [==============================] - 21s 245ms/step - loss: 2.0389e-05 - accuracy: 1.0000 - val_loss: 0.2903 - val_accuracy: 0.9565
# Epoch 17/50
# 87/87 [==============================] - 20s 226ms/step - loss: 1.5946e-05 - accuracy: 1.0000 - val_loss: 0.2903 - val_accuracy: 0.9565
# Epoch 18/50
# 87/87 [==============================] - 19s 219ms/step - loss: 1.3810e-05 - accuracy: 1.0000 - val_loss: 0.2946 - val_accuracy: 0.9554
# Epoch 19/50
# 87/87 [==============================] - 20s 224ms/step - loss: 1.0774e-05 - accuracy: 1.0000 - val_loss: 0.2932 - val_accuracy: 0.9565
# Epoch 20/50
# 87/87 [==============================] - 20s 224ms/step - loss: 9.7396e-06 - accuracy: 1.0000 - val_loss: 0.2988 - val_accuracy: 0.9554
# Epoch 21/50
# 87/87 [==============================] - 20s 224ms/step - loss: 7.3237e-06 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9543
# Epoch 22/50
# 87/87 [==============================] - 21s 238ms/step - loss: 6.8403e-06 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9554
# Epoch 23/50
# 87/87 [==============================] - 20s 226ms/step - loss: 5.7165e-06 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9543
# Epoch 24/50
# 87/87 [==============================] - 21s 244ms/step - loss: 4.7631e-06 - accuracy: 1.0000 - val_loss: 0.3009 - val_accuracy: 0.9543
# Epoch 25/50
# 87/87 [==============================] - 20s 229ms/step - loss: 4.4538e-06 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.9554
# Epoch 26/50
# 87/87 [==============================] - 19s 219ms/step - loss: 3.8918e-06 - accuracy: 1.0000 - val_loss: 0.3036 - val_accuracy: 0.9543
# Epoch 27/50
# 87/87 [==============================] - 20s 232ms/step - loss: 3.5605e-06 - accuracy: 1.0000 - val_loss: 0.3043 - val_accuracy: 0.9554
# Epoch 28/50
# 87/87 [==============================] - 19s 220ms/step - loss: 3.3782e-06 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 0.9554
# Epoch 29/50
# 87/87 [==============================] - 20s 233ms/step - loss: 2.8452e-06 - accuracy: 1.0000 - val_loss: 0.3076 - val_accuracy: 0.9554
# Epoch 30/50
# 87/87 [==============================] - 20s 224ms/step - loss: 2.6633e-06 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9565
# Epoch 31/50
# 87/87 [==============================] - 19s 219ms/step - loss: 2.4523e-06 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9554
# Epoch 32/50
# 87/87 [==============================] - 20s 231ms/step - loss: 2.1512e-06 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.9554
# Epoch 33/50
# 87/87 [==============================] - 20s 233ms/step - loss: 1.9962e-06 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.9565
# Epoch 34/50
# 87/87 [==============================] - 20s 229ms/step - loss: 1.7894e-06 - accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9565
# Epoch 35/50
# 87/87 [==============================] - 19s 218ms/step - loss: 1.7570e-06 - accuracy: 1.0000 - val_loss: 0.3147 - val_accuracy: 0.9554
# Epoch 36/50
# 87/87 [==============================] - 20s 232ms/step - loss: 1.5325e-06 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9565
# Epoch 37/50
# 87/87 [==============================] - 20s 225ms/step - loss: 1.4726e-06 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9554
# Epoch 38/50
# 87/87 [==============================] - 20s 225ms/step - loss: 1.2789e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9565
# Epoch 39/50
# 87/87 [==============================] - 20s 231ms/step - loss: 1.2691e-06 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9565
# Epoch 40/50
# 87/87 [==============================] - 19s 222ms/step - loss: 1.1499e-06 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9565
# Epoch 41/50
# 87/87 [==============================] - 20s 232ms/step - loss: 9.8570e-07 - accuracy: 1.0000 - val_loss: 0.3194 - val_accuracy: 0.9565
# Epoch 42/50
# 87/87 [==============================] - 20s 235ms/step - loss: 9.7580e-07 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9565
# Epoch 43/50
# 87/87 [==============================] - 20s 233ms/step - loss: 9.1251e-07 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9565
# Epoch 44/50
# 87/87 [==============================] - 20s 224ms/step - loss: 8.8052e-07 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.9565
# Epoch 45/50
# 87/87 [==============================] - 20s 224ms/step - loss: 7.8347e-07 - accuracy: 1.0000 - val_loss: 0.3193 - val_accuracy: 0.9565
# Epoch 46/50
# 87/87 [==============================] - 20s 228ms/step - loss: 7.3342e-07 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.9565
# Epoch 47/50
# 87/87 [==============================] - 19s 222ms/step - loss: 6.8967e-07 - accuracy: 1.0000 - val_loss: 0.3217 - val_accuracy: 0.9565
# Epoch 48/50
# 87/87 [==============================] - 20s 231ms/step - loss: 6.8017e-07 - accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.9565
# Epoch 49/50
# 87/87 [==============================] - 19s 218ms/step - loss: 6.1966e-07 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9565
# Epoch 50/50
# 87/87 [==============================] - 21s 239ms/step - loss: 5.6683e-07 - accuracy: 1.0000 - val_loss: 0.3247 - val_accuracy: 0.9565

# %%
# plotting the loss
plt.plot(history.history['loss'],label = 'Training loss')
plt.plot(history.history['val_loss'], label = 'Validation loss')
#plt.title('loss')
plt.legend()
plt.show()

# %%
# Both Validation and Training accuracy is shown here

plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
#plt.title('Accuracy')
plt.legend()
plt.show()

# %%
# CHECKING THE CONFUSION MATRIX

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
Y_pred = model_1.predict(test_set)
y_pred = np.argmax(Y_pred ,axis =1)
# Out:
# 20/20 [==============================] - 275s 14s/step

# %%
preds = model_1.predict(test_set,verbose=1)
predictions = preds.copy()
predictions[predictions <= 0.5] = 0
predictions[predictions > 0.5] = 1
# Out:
# 20/20 [==============================] - 5s 258ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = pd.DataFrame(data=confusion_matrix( y_true= test_set.classes, y_pred= y_pred, labels=[0, 1]), index=['Actual Brain Tumor','Actual Normal'],columns=['Predicted Brain Tumor','Predicted Normal'])
import seaborn as sns
sns.heatmap(cm,annot=True,fmt="d",cmap="BuPu")
# Out:
# <Axes: >

# %%
print('Classification Report')
target_names = ['Brain Tumor','Normal']
print(classification_report(test_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#  Brain Tumor       0.95      0.96      0.95       477
#       Normal       0.96      0.94      0.95       443
#
#     accuracy                           0.95       920
#    macro avg       0.95      0.95      0.95       920
# weighted avg       0.95      0.95      0.95       920

# %%
loss, acc = model_1.evaluate_generator(test_set, len(test_set))

print ("\n\n================================\n\n")
print ("Loss: {}".format(loss))
print ("Accuracy: {0:.2f} %".format(acc * 100))
print ("\n\n================================\n\n")

test_set.reset()
# Out:
# <ipython-input-36-0bfbb599d6c5>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, acc = model_1.evaluate_generator(test_set, len(test_set))
# ================================
#
#
# Loss: 0.26585644483566284
# Accuracy: 95.22 %
#
#
# ================================

# %%
result = model_1.evaluate(test_set,batch_size=128)
print("test_loss, test accuracy",result)
# Out:
# 20/20 [==============================] - 4s 205ms/step - loss: 0.2659 - accuracy: 0.9522
# test_loss, test accuracy [0.26585644483566284, 0.9521738886833191]

# %%
#Confusion Matrix and Classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

#Y_pred = model.predict_generator(validation_generator, nb_validation_samples //
#batch_size+1)
y_pred = np.argmax(preds, axis=1)

print('Confusion Matrix')
print(confusion_matrix(test_set.classes, y_pred))
# Out:
# Confusion Matrix
# [[458  19]
#  [ 25 418]]
